# %% [markdown]
# Extracting hourly temperature data from NOAA ISD (integrated surface database) weather data
#
# ish_parser python module is from:
# https://github.com/haydenth/ish_parser

# %%
# boilerplate includes
import sys
import os

import numpy as np
import matplotlib as mpl
#mpl.use('nbagg')
import matplotlib.pyplot as plt
#from mpl_toolkits.mplot3d import Axes3D

#import mpld3 # for outputting interactive html figures

import pandas as pd
import seaborn as sns

import ish_parser
import gzip
import ftplib
import io
import dateutil

from IPython.display import display, HTML
# %matplotlib notebook
plt.style.use('seaborn-notebook')

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Parameters
#
# Main parameter is a list of the weather station callsigns

# %%
# PARAMETERS 

RUNSETS = [ # callsign, timezone, start_date, end_date
           ['KSFO','-08:00', '1950-01-01','2016-01-01'],#
           ['KFAT','-08:00', '1950-01-01','2016-01-01'],#
           ['KJAX','-05:00', '1950-01-01','2016-01-01'],#
           ['KBUR','-08:00', '1973-01-01','2016-01-01'],#
           ['KIAH','-06:00', '1970-01-01','2016-01-01'],#
           ['KLAX','-08:00', '1950-01-01','2016-01-01'],#
           ['KMCO','-05:00', '1973-01-01','2016-01-01'],#
           ['KRIV','-08:00', '1950-01-01','2016-01-01'],#
           ['KTPA','-05:00', '1950-01-01','2016-01-01'],#
           ['KSAN','-08:00', '1950-01-01','2016-01-01'],#
           ['KMIA','-05:00', '1950-01-01','2016-01-01'],#
          ]

TEMPERATURE_DATADIR = '../data/temperatures/ISD'
TEMPERATURE_OUTDIR = '../data/temperatures'
SUPPRESS_FIGURE_DISPLAY = True

## parameters used in fetching

USE_CACHED_STATION_H5_FILES = True # Don't download new temperature files unless required
FTPHOST = 'ftp.ncdc.noaa.gov'
FETCH_STATIONS_LIST_FILE = True

## parameters used in cleaning

TEMP_COL = 'AT' # The label of the hourly temperature column we make/output

# Resampling and interpolation parameters
# spline order used for converting to on-the-hour and filling small gaps
BASE_INTERPOLATION_K = 1 # 1 for linear interpolation
# give special treatment to data gaps longer than...
POTENTIALLY_PROBLEMATIC_GAP_SIZE = pd.Timedelta('03:00:00')

# %% [markdown]
# ## Loop through all the sites/stations and run the sub-scripts
# Most of the time is actually consumed saving figure files

# %%
for STATION_CALLSIGN, LOCAL_TIME_OFFSET, START_DATE, END_DATE in RUNSETS:
    SUBNOTEBOOK_FLAG = True
    DATADIR = TEMPERATURE_DATADIR
    OUTDIR = TEMPERATURE_OUTDIR
    # %run -i "Fetching and parsing ISH.ipynb"
    # %run -i "Cleaning temperatures.ipynb"
# Out:
# Fetching and parsing  KSFO
# #### 724940 23234 range(1973, 2018)
# Using cached file: '../data/temperatures/ISD/724940-23234-AT.h5'
# Saving station data to: '../data/temperatures/ISD/724940-23234-AT.h5'
# #### 999999 23234 range(1948, 1973)
# Using cached file: '../data/temperatures/ISD/999999-23234-AT.h5'
# Saving station data to: '../data/temperatures/ISD/999999-23234-AT.h5'
# Saving combined data to: 'KSFO_AT.h5'
# CPU times: user 92 ms, sys: 48 ms, total: 140 ms
# Wall time: 138 ms
# Cleaning temperature data for  KSFO
# 488 duplicates
# removing 304 points
# removing 86 points
# removing 39 points
# removing 15 points
# removing 4 points
# removing 1 points
# removing 0 points
# # Potentially problematic gaps: 164
# Saving cleaned temp data to: ../data/temperatures/KSFO_AT_cleaned
# Fetching and parsing  KFAT
# #### 723890 93193 range(1941, 2018)
# Using cached file: '../data/temperatures/ISD/723890-93193-AT.h5'
# Saving station data to: '../data/temperatures/ISD/723890-93193-AT.h5'
# #### 999999 93193 range(1965, 1972)
# Using cached file: '../data/temperatures/ISD/999999-93193-AT.h5'
# Saving station data to: '../data/temperatures/ISD/999999-93193-AT.h5'
# Saving combined data to: 'KFAT_AT.h5'
# CPU times: user 72 ms, sys: 32 ms, total: 104 ms
# Wall time: 98.3 ms
# Cleaning temperature data for  KFAT
# 198 duplicates
# removing 76 points
# removing 30 points
# removing 8 points
# removing 8 points
# removing 4 points
# removing 3 points
# removing 1 points
# removing 0 points
# # Potentially problematic gaps: 79
# Saving cleaned temp data to: ../data/temperatures/KFAT_AT_cleaned
# Fetching and parsing  KJAX
# #### 722060 13889 range(1948, 2018)
# Using cached file: '../data/temperatures/ISD/722060-13889-AT.h5'
# Saving station data to: '../data/temperatures/ISD/722060-13889-AT.h5'
# #### 999999 13889 range(1966, 1973)
# Using cached file: '../data/temperatures/ISD/999999-13889-AT.h5'
# Saving station data to: '../data/temperatures/ISD/999999-13889-AT.h5'
# Saving combined data to: 'KJAX_AT.h5'
# CPU times: user 72 ms, sys: 36 ms, total: 108 ms
# Wall time: 105 ms
# Cleaning temperature data for  KJAX
# 116 duplicates
# removing 156 points
# removing 27 points
# removing 5 points
# removing 1 points
# removing 0 points
# # Potentially problematic gaps: 68
# Saving cleaned temp data to: ../data/temperatures/KJAX_AT_cleaned
# Fetching and parsing  KBUR
# #### 722880 23152 range(1943, 2018)
# Using cached file: '../data/temperatures/ISD/722880-23152-AT.h5'
# Saving station data to: '../data/temperatures/ISD/722880-23152-AT.h5'
# #### 722880 99999 range(2000, 2004)
# Using cached file: '../data/temperatures/ISD/722880-99999-AT.h5'
# Saving station data to: '../data/temperatures/ISD/722880-99999-AT.h5'
# #### 999999 23152 range(1948, 1970)
# Using cached file: '../data/temperatures/ISD/999999-23152-AT.h5'
# Saving station data to: '../data/temperatures/ISD/999999-23152-AT.h5'
# Saving combined data to: 'KBUR_AT.h5'
# CPU times: user 236 ms, sys: 32 ms, total: 268 ms
# Wall time: 261 ms
# Cleaning temperature data for  KBUR
# 680 duplicates
# removing 159 points
# removing 30 points
# removing 6 points
# removing 0 points
# # Potentially problematic gaps: 457
# Saving cleaned temp data to: ../data/temperatures/KBUR_AT_cleaned
# Fetching and parsing  KIAH
# #### 722430 12960 range(1973, 2018)
# Using cached file: '../data/temperatures/ISD/722430-12960-AT.h5'
# Saving station data to: '../data/temperatures/ISD/722430-12960-AT.h5'
# #### 999999 12960 range(1969, 1973)
# Using cached file: '../data/temperatures/ISD/999999-12960-AT.h5'
# Saving station data to: '../data/temperatures/ISD/999999-12960-AT.h5'
# Saving combined data to: 'KIAH_AT.h5'
# CPU times: user 72 ms, sys: 20 ms, total: 92 ms
# Wall time: 93.3 ms
# Cleaning temperature data for  KIAH
# 2120 duplicates
# removing 69 points
# removing 10 points
# removing 2 points
# removing 0 points
# # Potentially problematic gaps: 32
# Saving cleaned temp data to: ../data/temperatures/KIAH_AT_cleaned
# Fetching and parsing  KLAX
# #### 722950 23174 range(1944, 2018)
# Using cached file: '../data/temperatures/ISD/722950-23174-AT.h5'
# Saving station data to: '../data/temperatures/ISD/722950-23174-AT.h5'
# #### 999999 23174 range(1947, 1973)
# Using cached file: '../data/temperatures/ISD/999999-23174-AT.h5'
# Saving station data to: '../data/temperatures/ISD/999999-23174-AT.h5'
# Saving combined data to: 'KLAX_AT.h5'
# CPU times: user 80 ms, sys: 40 ms, total: 120 ms
# Wall time: 116 ms
# Cleaning temperature data for  KLAX
# 762 duplicates
# removing 206 points
# removing 9 points
# removing 0 points
# # Potentially problematic gaps: 7
# Saving cleaned temp data to: ../data/temperatures/KLAX_AT_cleaned
# Fetching and parsing  KMCO
# #### 722050 12815 range(1952, 2018)
# Using cached file: '../data/temperatures/ISD/722050-12815-AT.h5'
# Saving station data to: '../data/temperatures/ISD/722050-12815-AT.h5'
# #### 999999 12815 range(1971, 1972)
# Using cached file: '../data/temperatures/ISD/999999-12815-AT.h5'
# Saving station data to: '../data/temperatures/ISD/999999-12815-AT.h5'
# Saving combined data to: 'KMCO_AT.h5'
# CPU times: user 68 ms, sys: 36 ms, total: 104 ms
# Wall time: 99.1 ms
# Cleaning temperature data for  KMCO
# 1538 duplicates
# removing 126 points
# removing 12 points
# removing 0 points
# # Potentially problematic gaps: 16
# Saving cleaned temp data to: ../data/temperatures/KMCO_AT_cleaned
# Fetching and parsing  KRIV
# #### 722860 23119 range(1933, 2018)
# Using cached file: '../data/temperatures/ISD/722860-23119-AT.h5'
# Saving station data to: '../data/temperatures/ISD/722860-23119-AT.h5'
# #### 722860 99999 range(2000, 2008)
# Using cached file: '../data/temperatures/ISD/722860-99999-AT.h5'
# Saving station data to: '../data/temperatures/ISD/722860-99999-AT.h5'
# Saving combined data to: 'KRIV_AT.h5'
# CPU times: user 240 ms, sys: 52 ms, total: 292 ms
# Wall time: 286 ms
# Cleaning temperature data for  KRIV
# 464 duplicates
# removing 327 points
# removing 130 points
# removing 37 points
# removing 12 points
# removing 8 points
# removing 1 points
# removing 0 points
# # Potentially problematic gaps: 1309
# Saving cleaned temp data to: ../data/temperatures/KRIV_AT_cleaned
# Fetching and parsing  KTPA
# #### 722110 12842 range(1940, 2018)
# Using cached file: '../data/temperatures/ISD/722110-12842-AT.h5'
# Saving station data to: '../data/temperatures/ISD/722110-12842-AT.h5'
# #### 999999 12842 range(1948, 1973)
# Using cached file: '../data/temperatures/ISD/999999-12842-AT.h5'
# Saving station data to: '../data/temperatures/ISD/999999-12842-AT.h5'
# Saving combined data to: 'KTPA_AT.h5'
# CPU times: user 80 ms, sys: 40 ms, total: 120 ms
# Wall time: 115 ms
# Cleaning temperature data for  KTPA
# 3394 duplicates
# removing 254 points
# removing 34 points
# removing 0 points
# # Potentially problematic gaps: 278
# Saving cleaned temp data to: ../data/temperatures/KTPA_AT_cleaned
# Fetching and parsing  KSAN
# #### 722900 23188 range(1942, 2018)
# Using cached file: '../data/temperatures/ISD/722900-23188-AT.h5'
# Saving station data to: '../data/temperatures/ISD/722900-23188-AT.h5'
# #### 999999 23188 range(1948, 1973)
# Using cached file: '../data/temperatures/ISD/999999-23188-AT.h5'
# Saving station data to: '../data/temperatures/ISD/999999-23188-AT.h5'
# Saving combined data to: 'KSAN_AT.h5'
# CPU times: user 72 ms, sys: 40 ms, total: 112 ms
# Wall time: 107 ms
# Cleaning temperature data for  KSAN
# 2948 duplicates
# removing 360 points
# removing 59 points
# removing 18 points
# removing 5 points
# removing 5 points
# removing 1 points
# removing 0 points
# # Potentially problematic gaps: 168
# Saving cleaned temp data to: ../data/temperatures/KSAN_AT_cleaned
# Fetching and parsing  KMIA
# #### 722020 12839 range(1973, 2018)
# Using cached file: '../data/temperatures/ISD/722020-12839-AT.h5'
# Saving station data to: '../data/temperatures/ISD/722020-12839-AT.h5'
# #### 999999 12839 range(1948, 1973)
# Using cached file: '../data/temperatures/ISD/999999-12839-AT.h5'
# Saving station data to: '../data/temperatures/ISD/999999-12839-AT.h5'
# Saving combined data to: 'KMIA_AT.h5'
# CPU times: user 80 ms, sys: 36 ms, total: 116 ms
# Wall time: 110 ms
# Cleaning temperature data for  KMIA
# 2616 duplicates
# removing 642 points
# removing 64 points
# removing 3 points
# removing 1 points
# removing 0 points
# # Potentially problematic gaps: 157
# Saving cleaned temp data to: ../data/temperatures/KMIA_AT_cleaned

# %% [markdown]
# ## prepare temperature CSV for MedFoes input

# %%
for RUNSET, LOCAL_TIME_OFFSET, START_DATE, END_DATE in RUNSETS:
    
    # convert from UTC to a *fixed offset* approximating local (solar time would be better, but this is good enough)
    # Note: not just the local timezone, because daylight-savings time is a pointless complication
    # convert the LOCAL_TIME_OFFSET string to number of seconds
    tmp = LOCAL_TIME_OFFSET.split(':')
    tmp = int(tmp[0])*3600+int(tmp[1])*60
    # create a timezone offset
    sitetz = dateutil.tz.tzoffset(LOCAL_TIME_OFFSET, tmp)
    
    ## Load Temperature data
    tfile = os.path.join(TEMPERATURE_OUTDIR, "{}_AT_cleaned.h5".format(RUNSET))
    tempdf = pd.read_hdf(tfile, 'table')
    # apply the timezone conversion
    tempdf.index = tempdf.index.tz_convert(sitetz)

    ## Save the desired date range as a CSV file
    # note: the date ranges were determined by inspecting the full temperature data
    # and excluding problematic early dates (big gaps, lots of outliers, ect.)
    outfn = os.path.join(TEMPERATURE_OUTDIR, "{}_AT_cleaned_trimmed".format(RUNSET))
    t = tempdf.loc[START_DATE:]
    print("Saving {} {} to {} : {}.csv".format(RUNSET, t.index[0], t.index[-1], outfn))
    t.to_csv(outfn+'.csv', index_label='datetime')
# Out:
# Saving KSFO 1950-01-01 00:00:00-08:00 to 2017-05-16 15:00:00-08:00 : ../data/temperatures/KSFO_AT_cleaned_trimmed.csv
# Saving KFAT 1950-01-01 00:00:00-08:00 to 2017-05-17 15:00:00-08:00 : ../data/temperatures/KFAT_AT_cleaned_trimmed.csv
# Saving KJAX 1950-01-01 00:00:00-05:00 to 2017-05-17 18:00:00-05:00 : ../data/temperatures/KJAX_AT_cleaned_trimmed.csv
# Saving KBUR 1973-01-01 00:00:00-08:00 to 2017-05-17 15:00:00-08:00 : ../data/temperatures/KBUR_AT_cleaned_trimmed.csv
# Saving KIAH 1970-01-01 00:00:00-06:00 to 2017-05-16 17:00:00-06:00 : ../data/temperatures/KIAH_AT_cleaned_trimmed.csv
# Saving KLAX 1950-01-01 00:00:00-08:00 to 2017-05-15 15:00:00-08:00 : ../data/temperatures/KLAX_AT_cleaned_trimmed.csv
# Saving KMCO 1973-01-01 00:00:00-05:00 to 2017-05-17 18:00:00-05:00 : ../data/temperatures/KMCO_AT_cleaned_trimmed.csv
# Saving KRIV 1950-01-01 00:00:00-08:00 to 2017-05-17 15:00:00-08:00 : ../data/temperatures/KRIV_AT_cleaned_trimmed.csv
# Saving KTPA 1950-01-01 00:00:00-05:00 to 2017-05-17 18:00:00-05:00 : ../data/temperatures/KTPA_AT_cleaned_trimmed.csv
# Saving KSAN 1950-01-01 00:00:00-08:00 to 2017-05-16 15:00:00-08:00 : ../data/temperatures/KSAN_AT_cleaned_trimmed.csv
# Saving KMIA 1950-01-01 00:00:00-05:00 to 2017-05-16 18:00:00-05:00 : ../data/temperatures/KMIA_AT_cleaned_trimmed.csv
